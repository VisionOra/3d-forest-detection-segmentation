# %% [markdown]
# # Evaluation Function

# %%
import json
import numpy as np
from PIL import Image
import os

def load_json(path):
    with open(path, "r") as file:
        data = json.load(file)
    return data

def bb_intersection_over_union(box1, box2):
    # determine the (x, y)-coordinates of the intersection rectangle
    x1, y1, w1, h1 = box1
    x2, y2, w2, h2 = box2

    # Calculate the (x, y)-coordinates of the intersection rectangle
    xi1 = max(x1, x2)
    yi1 = max(y1, y2)
    xi2 = min(x1+w1, x2+w2)
    yi2 = min(y1+h1, y2+h2)

    # Compute the area of intersection rectangle
    inter_area = max(0, xi2 - xi1 + 1) * max(0, yi2 - yi1 + 1)

    # Compute the area of both the prediction and ground-truth rectangles
    box1_area = w1 * h1
    box2_area = w2 * h2

    # Compute the intersection over union by taking the intersection area
    # and dividing it by the sum of prediction + ground-truth areas - the intersection area
    iou = inter_area / float(box1_area + box2_area - inter_area)

    # return the intersection over union value
    return iou

def calculate_iou_list(ground_truth, predictions):
    results = []
    for gt in ground_truth:
        iou_values = [bb_intersection_over_union(gt, pred) for pred in predictions]
        results.append(iou_values)
    return results



base_path = "/forest_3d_app/yolov5/trims_dataset/test/"
ground_truths_path = base_path +  "_annotations.coco.json"
truths = load_json(ground_truths_path)


images, annotations = truths["images"], truths["annotations"]

bb_intersection_over_union([187, 305, 165, 171], [187, 305, 165, 171])
# Out:
# 1.0241767702130713

# %%
annotations
# Out:
# [{'area': 3577,
#   'bbox': [260, 81, 98, 36.5],
#   'category_id': 1,
#   'id': 0,
#   'image_id': 0,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 7504,
#   'bbox': [242, 111, 112, 67],
#   'category_id': 1,
#   'id': 1,
#   'image_id': 0,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 13255,
#   'bbox': [222, 184, 120.5, 110],
#   'category_id': 1,
#   'id': 2,
#   'image_id': 0,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 6742.25,
#   'bbox': [253, 297, 90.5, 74.5],
#   'category_id': 1,
#   'id': 3,
#   'image_id': 0,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 6359.25,
#   'bbox': [242, 370, 91.5, 69.5],
#   'category_id': 1,
#   'id': 4,
#   'image_id': 0,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 8952.75,
#   'bbox': [237, 452, 103.5, 86.5],
#   'category_id': 1,
#   'id': 5,
#   'image_id': 0,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 8341.5,
#   'bbox': [244, 539, 100.5, 83],
#   'category_id': 1,
#   'id': 6,
#   'image_id': 0,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 11904,
#   'bbox': [443, 78, 93, 128],
#   'category_id': 1,
#   'id': 7,
#   'image_id': 0,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 4794,
#   'bbox': [1, 448, 34, 141],
#   'category_id': 1,
#   'id': 8,
#   'image_id': 1,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 4760,
#   'bbox': [83, 416, 59.5, 80],
#   'category_id': 1,
#   'id': 9,
#   'image_id': 1,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 41503.5,
#   'bbox': [144, 208, 207, 200.5],
#   'category_id': 1,
#   'id': 10,
#   'image_id': 1,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 26480,
#   'bbox': [223, 49, 160, 165.5],
#   'category_id': 1,
#   'id': 11,
#   'image_id': 1,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 2914,
#   'bbox': [136, 392, 62, 47],
#   'category_id': 1,
#   'id': 12,
#   'image_id': 1,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 2461,
#   'bbox': [57, 452, 46, 53.5],
#   'category_id': 1,
#   'id': 13,
#   'image_id': 1,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 9024,
#   'bbox': [253, 409, 96, 94],
#   'category_id': 1,
#   'id': 14,
#   'image_id': 2,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 5885.5,
#   'bbox': [250, 519, 74.5, 79],
#   'category_id': 1,
#   'id': 15,
#   'image_id': 2,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 5791.5,
#   'bbox': [300, 367, 71.5, 81],
#   'category_id': 1,
#   'id': 16,
#   'image_id': 3,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 3300,
#   'bbox': [414, 380, 50, 66],
#   'category_id': 1,
#   'id': 17,
#   'image_id': 3,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 1872,
#   'bbox': [239, 369, 32, 58.5],
#   'category_id': 1,
#   'id': 18,
#   'image_id': 3,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 1200,
#   'bbox': [478, 402, 37.5, 32],
#   'category_id': 1,
#   'id': 19,
#   'image_id': 3,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 635.5,
#   'bbox': [532, 404, 20.5, 31],
#   'category_id': 1,
#   'id': 20,
#   'image_id': 3,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 961,
#   'bbox': [574, 408, 31, 31],
#   'category_id': 1,
#   'id': 21,
#   'image_id': 3,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 10934.25,
#   'bbox': [325, 497, 119.5, 91.5],
#   'category_id': 1,
#   'id': 22,
#   'image_id': 3,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 9963,
#   'bbox': [436, 490, 121.5, 82],
#   'category_id': 1,
#   'id': 23,
#   'image_id': 3,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 6162,
#   'bbox': [556, 508, 78, 79],
#   'category_id': 1,
#   'id': 24,
#   'image_id': 3,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 28383.25,
#   'bbox': [187, 305, 165.5, 171.5],
#   'category_id': 1,
#   'id': 25,
#   'image_id': 4,
#   'iscrowd': 0,
#   'segmentation': []},
#  {'area': 48688,
#   'bbox': [199, 58, 179, 272],
#   'category_id': 1,
#   'id': 26,
#   'image_id': 4,
#   'iscrowd': 0,
#   'segmentation': []}]

# %% [markdown]
# # Yolo V3

# %%
import cv2
import numpy as np

import matplotlib.pyplot as plt

def load_yolo_model(weights, config, classes):
    net = cv2.dnn.readNet(weights, config)
    layer_names = net.getLayerNames()
    output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]
    class_names = [line.strip() for line in open(classes)]

    return net, output_layers, class_names

def predict_image(image_path, net, output_layers, class_names):
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    height, width, _ = img.shape

    blob = cv2.dnn.blobFromImage(img, 1/255.0, (416, 416), (0, 0, 0), swapRB=False, crop=False)
    net.setInput(blob)
    layer_outputs = net.forward(output_layers)

    boxes, confidences, class_ids = [], [], []

    for output in layer_outputs:
        for detection in output:
            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]

            if confidence >= 0.50:
                center_x, center_y, w, h = (detection[0:4] * np.array([width, height, width, height])).astype('int')
                
                
                
                x = int(center_x - w / 2)
                y = int(center_y - h / 2)
                
                
                boxes.append([x, y, w, h])
                confidences.append(float(confidence))
                class_ids.append(class_id)
    
#     indices = cv2.dnn.NMSBoxes(boxes, confidences, 0.0, 0.0)
    print(boxes)
    for i in boxes:
        
            
        box = i
        x, y, w, h = box
        color = (0, 255, 0)
        cv2.rectangle(img, (x, y), (x + w, y + h), color, 2)
        cv2.putText(img, "", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
        
    plt.imshow(img)
    plt.show()
    return boxes

# %%
weights = "/forest_3d_app/3d_forest/forest_3d_app/models/models/detection/hvp/yolov3.weights"
config = "/forest_3d_app/3d_forest/forest_3d_app/models/models/detection/hvp/yolov3.cfg"
classes = "/forest_3d_app/3d_forest/forest_3d_app/models/models/detection/hvp/obj.names"
image_path = "/forest_3d_app/yolov5/trims_dataset/test/160_2-170_2_slam_slice_no_15_jpeg.rf.22e75754361c4b834a74ec5febe1f3c9.jpg"
annotation_path = "/forest_3d_app/yolov5/trims_dataset/test/"
net, output_layers, class_names = load_yolo_model(weights, config, classes)
prediction = predict_image(image_path, net, output_layers, class_names)
# Out:
# [[296, 78, 63, 72], [327, 72, 54, 70], [329, 148, 46, 66], [234, 188, 51, 74], [287, 237, 47, 75], [332, 278, 44, 53], [329, 270, 50, 64], [290, 319, 36, 65], [328, 331, 37, 58], [324, 348, 43, 52], [321, 341, 49, 61], [247, 366, 58, 72], [304, 385, 44, 58], [297, 390, 57, 71]]

# %% [markdown]
# # Draw Ground Truths

# %%
img = cv2.imread(image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
bbox = [[187, 305, 165, 171], [199, 58, 179, 272]]
for box in bbox:
    color = (0, 255, 0)
    x, y, w, h = box
    print((x, y), (x + w, y + h))
    cv2.rectangle(img, (x, y), (x + w, y + h), color, 2)

plt.imshow(img)
plt.show()
# Out:
# (187, 305) (352, 476)
# (199, 58) (378, 330)

# %%
for image in images:
    # Getting file path
    image_path = base_path + image["file_name"]
    print(image_path)
    # Getting ground truth
    ground_truth_bbox = []
    for annotation in annotations:
        if image['id'] == annotation['image_id']:
            ground_truth_bbox.append(annotation["bbox"])
    
#     print("Ground Truth")
    print(ground_truth_bbox)
# #     break
#     # Getting prediction
    prediction = predict_image(image_path, net, output_layers, class_names)
    print("prediction")
    print(prediction)
    iou = calculate_iou_list(ground_truth_bbox, prediction)
    print("IOU   ", iou)
# Out:
# /forest_3d_app/yolov5/trims_dataset/test/170_2-200_2_slam_slice_no_53_jpeg.rf.cc7864efcdd7186ff0c0465d2585419d.jpg
# [[260, 81, 98, 36.5], [242, 111, 112, 67], [222, 184, 120.5, 110], [253, 297, 90.5, 74.5], [242, 370, 91.5, 69.5], [237, 452, 103.5, 86.5], [244, 539, 100.5, 83], [443, 78, 93, 128]]
# [[354, 73, 52, 73], [446, 69, 64, 77], [547, 84, 24, 58], [250, 113, 79, 64], [349, 103, 51, 66], [255, 119, 73, 62], [542, 140, 20, 58], [521, 152, 23, 62], [539, 158, 22, 60], [131, 192, 27, 50], [227, 181, 55, 63], [351, 170, 45, 75], [265, 192, 68, 69], [241, 234, 71, 65], [131, 247, 26, 66], [252, 249, 66, 55], [555, 278, 15, 71], [256, 299, 70, 61], [267, 297, 63, 65], [523, 300, 19, 69], [487, 326, 26, 67], [550, 328, 19, 64], [252, 373, 74, 65], [531, 378, 25, 65], [249, 450, 73, 73], [260, 459, 72, 76], [443, 467, 59, 70], [539, 473, 38, 54], [536, 469, 44, 63], [536, 507, 45, 47], [248, 532, 67, 64], [447, 534, 50, 52], [250, 537, 79, 78], [267, 546, 65, 67], [441, 573, 41, 45], [485, 571, 49, 49], [482, 569, 53, 54], [550, 573, 42, 47]]
# prediction
# [[354, 73, 52, 73], [446, 69, 64, 77], [547, 84, 24, 58], [250, 113, 79, 64], [349, 103, 51, 66], [255, 119, 73, 62], [542, 140, 20, 58], [521, 152, 23, 62], [539, 158, 22, 60], [131, 192, 27, 50], [227, 181, 55, 63], [351, 170, 45, 75], [265, 192, 68, 69], [241, 234, 71, 65], [131, 247, 26, 66], [252, 249, 66, 55], [555, 278, 15, 71], [256, 299, 70, 61], [267, 297, 63, 65], [523, 300, 19, 69], [487, 326, 26, 67], [550, 328, 19, 64], [252, 373, 74, 65], [531, 378, 25, 65], [249, 450, 73, 73], [260, 459, 72, 76], [443, 467, 59, 70], [539, 473, 38, 54], [536, 469, 44, 63], [536, 507, 45, 47], [248, 532, 67, 64], [447, 534, 50, 52], [250, 537, 79, 78], [267, 546, 65, 67], [441, 573, 41, 45], [485, 571, 49, 49], [482, 569, 53, 54], [550, 573, 42, 47]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-32e15343f757> in <module>
#      17     print(prediction)
#      18     iou = calculate_iou_list(ground_truth_bbox, prediction)
# ---> 19     print("IOU   ", avg(iou))
#
# NameError: name 'avg' is not defined

# %% [markdown]
# # Yolo 5

# %%
import torch
from PIL import Image

def prediction_function(weights, image_path):
    # Load model
    model = torch.hub.load('ultralytics/yolov5', 'custom', weights)
    
    # Load weights
#     model.load_state_dict(torch.load(weights))
    
    # Load image
    img = Image.open(image_path)

    # Get predictions
    results = model(img)

    # Show results
    results.show()

    return results
weights = "/forest_3d_app/yolov5/runs/train/exp7/weights/best.pt"
source = "/forest_3d_app/yolov5/trims_dataset/test/160_2-170_2_slam_slice_no_15_jpeg.rf.22e75754361c4b834a74ec5febe1f3c9.jpg"

results = prediction_function(weights, source)
# Usage:
# preds = prediction_function('path_to_weights/best.pt', 'path_to_image.jpg')
# print(preds)
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-6-28 Python-3.9.16 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3070, 7979MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# <PIL.Image.Image image mode=RGB size=640x640>
