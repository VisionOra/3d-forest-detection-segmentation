# %%
import re
import matplotlib.pyplot as plt

def read_losses(file_path):
    with open(file_path, 'r') as f:
        content = f.read()

    pattern = r"total_loss = (\d+\.\d+)"
    total_losses = [float(loss) for loss in re.findall(pattern, content)]

    return total_losses


def read_losses(file_path):
    with open(file_path, 'r') as f:
        content = f.read()

    pattern = r"total_loss = (\d+\.\d+)"
    total_losses = [float(loss) for loss in re.findall(pattern, content)]

    return total_losses


def read_iou_losses(file_path):
    with open(file_path, 'r') as f:
        content = f.read()

    pattern = r"iou_loss = (\d+\.\d+)"
    total_losses = [float(loss) for loss in re.findall(pattern, content)]

    return total_losses

def read_class_losses(file_path):
    with open(file_path, 'r') as f:
        content = f.read()

    pattern = r"class_loss = (\d+\.\d+)"
    total_losses = [float(loss) for loss in re.findall(pattern, content)]

    return total_losses


def plot_losses(total_losses, title, x_label, y_label):
    plt.plot(total_losses)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.grid()
    plt.show()

if __name__ == "__main__":
    file_path = "/forest_3d_app/darknet/training.log"
    
    # Total Loss
    total_losses = read_losses(file_path)
    plot_losses(total_losses, title = 'Losses Over Time', x_label = 'Iteration', y_label = 'Total Loss')
    
    # Total IOU loss
    total_iou_losses = read_iou_losses(file_path)
    plot_losses(total_iou_losses, title = 'IOU Losses Over Time', x_label = 'Iteration', y_label = 'Total Loss')
    
    # Total class loss
    total_class_losses = read_class_losses(file_path)
    plot_losses(total_class_losses, title = 'class Losses Over Time', x_label = 'Iteration', y_label = 'Total Loss')

# %%
# each channel RGB channel (convolution)
# Out:
#   File "<ipython-input-1-5d1b656de9be>", line 1
#     each channel RGB
#                ^
# SyntaxError: invalid syntax

# %%
R
